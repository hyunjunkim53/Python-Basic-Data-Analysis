# %% [markdown]
# # 5. 파일 저장

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 윈도우
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
x = [1, 2, 3]
y = [2, 4, 8]

# %%
plt.plot(x, y)
plt.savefig('graph.png', dpi=100) # dpi (dots per inch): 1인치 안에 점이 몇 개 들어가는지 나타내는 해상도 단위

# %%
plt.figure(dpi=200) # 화면의 dpi 설정
plt.plot(x, y)
plt.savefig('graph_200.png', dpi=100) # 파일의 dpi 설정
